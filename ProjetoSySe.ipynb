# %%
# !pip install google-genai

# %%
# !apt-get install python3-tk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-tk is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# !pip install requests

# %%
# !pip install pyttsx3

# %%
# !pip install beautifulsoup4

# %%
# !pip install lxml

# %%
# !pip install remi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 kB 10.5 MB/s eta 0:00:00
# ...

# %%
# !apt-get update && apt-get install -y libespeak-ng-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,944 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,934 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import pyttsx3
import requests
from bs4 import BeautifulSoup
import sys # Importe o módulo sys


# --- Funções Auxiliares ---


def falar(texto):
  """Realiza a leitura por voz do texto."""
  engine = pyttsx3.init()
  engine.setProperty('voice', 'brazil')
  engine.say(texto)
  engine.runAndWait()


def buscar_informacoes(duvida):
  """Simula a busca de informações (substitua com sua lógica real)."""
  resultados_simulados = [
  {"problema": f"Possíveis ataques relacionados a {duvida}:", "solucao": "Verifique as configurações de segurança."},
  {"problema": f"Prevenção contra {duvida}:", "solucao": "Mantenha seu software atualizado."},
  ]
  return resultados_simulados


# --- Agentes do Chatbot ---


def agente_buscador():
  """Agente Buscador (Etapa 1)."""
  print("Olá, sou a CySe, sua ChatBot de ajuda para assuntos sobre Cyber Segurança.")
  print("Escolha uma das opções abaixo:")
  print("A - Informações de Cyber Segurança")
  print("B - Ajuda para um problema específico")


  escolha = input("Digite A ou B: ").upper()


  if escolha == "A":
   agente_especialista1()
  elif escolha == "B":
   agente_indicador1()
  else:
   print("Opção inválida. Escolha A ou B.")
   agente_buscador() # Recomeça


def agente_especialista1():
  """Agente Especialista 1 (Etapa 2)."""
  informacoes = [
  {"problema": "Phishing (e-mails falsos):", "solucao": "Não clique em links suspeitos."},
  {"problema": "Malware (vírus):", "solucao": "Use antivírus."},
  {"problema": "Senhas Fracas:", "solucao": "Use senhas fortes."},
  {"problema": "DDoS:", "solucao": "Proteja sua rede."},
  {"problema": "Engenharia Social:", "solucao": "Desconfie de pedidos de info."},
  ]


  print("\nTipos Comuns de Ataques Cibernéticos:")
  for info in informacoes:
   print(f"- {info['problema']} {info['solucao']}")
   falar(info["problema"] + info["solucao"])


  input("\nPressione Enter para voltar ao início.")
  agente_buscador()


def agente_indicador1():
  """Agente Indicador 1 (Etapa 3)."""
  duvida = input("\nDigite aqui sua dúvida/tema: ")
  agente_especialista2(duvida)


def agente_especialista2(duvida):
  """Agente Especialista 2 (Etapa 4)."""
  resultados = buscar_informacoes(duvida)


  print(f"\nSua Dúvida: {duvida}")
  if resultados:
   print("\nResultados Encontrados:")
  for resultado in resultados:
   print(f"- {resultado['problema']} {resultado['solucao']}")
   falar(resultado["problema"] + resultado["solucao"])
  else:
   print("\nNenhum resultado encontrado.")


  print("\nEspero que você tenha gostado da minha ajuda.")
  print("Escolha A para mais ajuda ou B para problema resolvido.")
  escolha = input("Digite A ou B: ").upper()


  if escolha == "A":
   agente_buscador()
  elif escolha == "B":
   agente_indicador2()
  else:
   print("Opção inválida.")
   agente_especialista2(duvida)


def agente_indicador2():
  """Agente Indicador 2 (Etapa 5)."""
  print("\nFico feliz em poder ter ajudado. Obrigado e se precisar, me chame!")
  sys.exit() # Adicione sys.exit() para encerrar o programa


 # --- Iniciar o Chatbot ---


agente_buscador()
# Out:
# Olá, sou a CySe, sua ChatBot de ajuda para assuntos sobre Cyber Segurança.
# Escolha uma das opções abaixo:
# A - Informações de Cyber Segurança
# B - Ajuda para um problema específico
# Digite A ou B: a
#
# Tipos Comuns de Ataques Cibernéticos:
# - Phishing (e-mails falsos): Não clique em links suspeitos.
# - Malware (vírus): Use antivírus.
# - Senhas Fracas: Use senhas fortes.
# - DDoS: Proteja sua rede.
# - Engenharia Social: Desconfie de pedidos de info.
#
# Pressione Enter para voltar ao início.
# Olá, sou a CySe, sua ChatBot de ajuda para assuntos sobre Cyber Segurança.
# Escolha uma das opções abaixo:
# A - Informações de Cyber Segurança
# B - Ajuda para um problema específico
# Digite A ou B: b
#
# Digite aqui sua dúvida/tema: ransoware
#
# Sua Dúvida: ransoware
#
# Resultados Encontrados:
# - Possíveis ataques relacionados a ransoware: Verifique as configurações de segurança.
# - Prevenção contra ransoware: Mantenha seu software atualizado.
#
# Nenhum resultado encontrado.
# ...
